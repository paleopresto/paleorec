# %%
# %run train_lstm.py -e 150 -l 0.01
# Out:
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 1/200 Iteration: 100 Loss: 1.0490630865097046
# Epoch: 3/200 Iteration: 200 Loss: 0.7699901461601257
# Epoch: 4/200 Iteration: 300 Loss: 0.7910447716712952
# Epoch: 6/200 Iteration: 400 Loss: 0.8342747092247009
# Epoch: 8/200 Iteration: 500 Loss: 0.6816522479057312
# Epoch: 9/200 Iteration: 600 Loss: 0.7223721146583557
# Epoch: 11/200 Iteration: 700 Loss: 0.6689605116844177
# Epoch: 12/200 Iteration: 800 Loss: 0.7412679195404053
# Epoch: 14/200 Iteration: 900 Loss: 0.7497067451477051
# Epoch: 16/200 Iteration: 1000 Loss: 0.7470752596855164
# Epoch: 17/200 Iteration: 1100 Loss: 0.7227049469947815
# Epoch: 19/200 Iteration: 1200 Loss: 0.6460109353065491
# Epoch: 20/200 Iteration: 1300 Loss: 0.7040223479270935
# Epoch: 22/200 Iteration: 1400 Loss: 0.7127800583839417
# ...
