# %%
# %run train_lstm.py -e 200 -l 0.01
# Out:
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/200 Loss: 0.7341760396957397
# Epoch: 1/200 Loss: 0.6565504670143127
# Epoch: 2/200 Loss: 0.6319013833999634
# Epoch: 3/200 Loss: 0.6199983954429626
# Epoch: 4/200 Loss: 0.6140568256378174
# Epoch: 5/200 Loss: 0.6126397848129272
# Epoch: 6/200 Loss: 0.6095684766769409
# Epoch: 7/200 Loss: 0.6041202545166016
# Epoch: 8/200 Loss: 0.6015970706939697
# Epoch: 9/200 Loss: 0.6003443002700806
# Epoch: 10/200 Loss: 0.6003894805908203
# Epoch: 11/200 Loss: 0.6000739336013794
# Epoch: 12/200 Loss: 0.6021687984466553
# Epoch: 13/200 Loss: 0.5976817607879639
# Epoch: 14/200 Loss: 0.5982385277748108
# Epoch: 15/200 Loss: 0.5970697999000549
# Epoch: 16/200 Loss: 0.5937584638595581
# Epoch: 17/200 Loss: 0.5947375893592834
# Epoch: 18/200 Loss: 0.5971514582633972
# Epoch: 19/200 Loss: 0.5939738750457764
# ...

# %%
# Trianing data on combination of wiki files and Pages2k and Temp12k
# %run train_lstm_validation.py -e 50 -l 0.01
# Out:
#  Counter({'Wood': 1429, 'MarineSediment': 483, 'Coral': 114, 'GlacierIce': 37, 'LakeSediment': 33, 'Speleothem': 9, 'h': 6, 'Sclerosponge': 5, 'MollusckShell': 1, 'Hybrid': 1})
#
#  Counter({'Wood': 370, 'MarineSediment': 103, 'Coral': 33, 'GlacierIce': 9, 'LakeSediment': 6, 'Speleothem': 3, 'h': 3, 'Hybrid': 1, 'Sclerosponge': 1})
#
#  {'Wood': 0.6746931067044382, 'GlacierIce': 0.017469310670443813, 'Coral': 0.053824362606232294, 'MarineSediment': 0.22804532577903683, 'Speleothem': 0.00424929178470255, 'LakeSediment': 0.015580736543909348, 'Sclerosponge': 0.002360717658168083, 'h': 0.0028328611898017, 'MollusckShell': 0.00047214353163361664, 'Hybrid': 0.00047214353163361664}
#
#  {'Wood': 0.6994328922495274, 'MarineSediment': 0.1947069943289225, 'Speleothem': 0.005671077504725898, 'GlacierIce': 0.017013232514177693, 'Coral': 0.062381852551984876, 'LakeSediment': 0.011342155009451797, 'Hybrid': 0.001890359168241966, 'h': 0.005671077504725898, 'Sclerosponge': 0.001890359168241966}
# ...

# %%
# Training data on 4 datasets from lipdverse.org
# %run train_lstm_validation.py -e 200 -l 0.01
# Out:
# len(int_to_vocab) before :  403
# len(int_to_vocab) after :  403
#
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/200 Training Loss: 1.7218590912364777 Validation Loss: 2.023317190317007
# Epoch: 1/200 Training Loss: 1.0128637035687764 Validation Loss: 2.151866601063655
# Epoch: 2/200 Training Loss: 0.9273411228543236 Validation Loss: 2.2580690338061404
# Epoch: 3/200 Training Loss: 0.8870174845059713 Validation Loss: 2.3133934827951284
# Epoch: 4/200 Training Loss: 0.8658581835883005 Validation Loss: 2.33807301062804
# Epoch: 5/200 Training Loss: 0.8504116716839019 Validation Loss: 2.40308887224931
# Epoch: 6/200 Training Loss: 0.8390888673918587 Validation Loss: 2.463877017681415
# Epoch: 7/200 Training Loss: 0.8347091566948663 Validation Loss: 2.4686799462024984
# Epoch: 8/200 Training Loss: 0.8276639501253764 Validation Loss: 2.4850093768193173
# ...

# %%
# Training data on 4 datasets from lipdverse.org
# %run train_lstm_validation.py -e 100 -l 0.01 -u
# Out:
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/100 Training Loss: 1.672917512227904 Validation Loss: 3.836607346167931
# Epoch: 1/100 Training Loss: 1.2771616330686606 Validation Loss: 4.10936439037323
# Epoch: 2/100 Training Loss: 1.2531712887422093 Validation Loss: 4.250833850640517
# Epoch: 3/100 Training Loss: 1.2444039808129364 Validation Loss: 4.307036803318904
# Epoch: 4/100 Training Loss: 1.2385603526853166 Validation Loss: 4.401174270189726
# Epoch: 5/100 Training Loss: 1.2341865244901404 Validation Loss: 4.488840451607337
# Epoch: 6/100 Training Loss: 1.2316610104632828 Validation Loss: 4.532051737491901
# Epoch: 7/100 Training Loss: 1.2284217184444644 Validation Loss: 4.54165845650893
# Epoch: 8/100 Training Loss: 1.225733517475848 Validation Loss: 4.569267924015339
# Epoch: 9/100 Training Loss: 1.2220611774696495 Validation Loss: 4.6503954117114725
# ...

# %%
#Only training data, no validation data
# %run train_lstm.py -e 200 -l 0.01
# Out:
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/200 Training Loss: 1.680605880176748
# Epoch: 1/200 Training Loss: 1.0560515973404163
# Epoch: 2/200 Training Loss: 0.9415406825888248
# Epoch: 3/200 Training Loss: 0.8948926666310726
# Epoch: 4/200 Training Loss: 0.869129950763615
# Epoch: 5/200 Training Loss: 0.852515606024793
# Epoch: 6/200 Training Loss: 0.8402206925035433
# Epoch: 7/200 Training Loss: 0.8330115530327076
# Epoch: 8/200 Training Loss: 0.8262374401092529
# Epoch: 9/200 Training Loss: 0.8213775690275295
# Epoch: 10/200 Training Loss: 0.8159374526438822
# Epoch: 11/200 Training Loss: 0.8113100665216227
# Epoch: 12/200 Training Loss: 0.8086712815379369
# Epoch: 13/200 Training Loss: 0.8073790360043067
# Epoch: 14/200 Training Loss: 0.8038861464908105
# Epoch: 15/200 Training Loss: 0.8019032633031598
# ...

# %%
#Only training data, no validation data, testing for CrossEntropy
# %run train_lstm.py -e 150 -l 0.01
# Out:
# list of len {'1': 15, '2': 123, '3': 228, '3_units': 152, '4': 411, '5': 646, '6': 652}
# 2207
#
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/150 Training Loss: 1.6750035963275216
# Epoch: 1/150 Training Loss: 1.0146308938662212
# Epoch: 2/150 Training Loss: 0.9192816913127899
# Epoch: 3/150 Training Loss: 0.8810582716356624
# Epoch: 4/150 Training Loss: 0.8606872337334084
# Epoch: 5/150 Training Loss: 0.8487372800256267
# Epoch: 6/150 Training Loss: 0.8383911857099244
# Epoch: 7/150 Training Loss: 0.831839630098054
# Epoch: 8/150 Training Loss: 0.8262073745330175
# Epoch: 9/150 Training Loss: 0.8233988903688662
# Epoch: 10/150 Training Loss: 0.820363182461623
# Epoch: 11/150 Training Loss: 0.8164975814747087
# Epoch: 12/150 Training Loss: 0.814727676637245
# Epoch: 13/150 Training Loss: 0.812167024973667
# ...

# %%
# %run train_lstm.py -e 150 -l 0.01 -u
# Out:
# list of len {'1': 15, '2': 123, '3': 228, '3_units': 152, '4': 411, '5': 646, '6': 652}
# 2207
#
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/150 Training Loss: 1.6382625419082064
# Epoch: 1/150 Training Loss: 1.2737513961214009
# Epoch: 2/150 Training Loss: 1.2523595690727234
# Epoch: 3/150 Training Loss: 1.2432739472750463
# Epoch: 4/150 Training Loss: 1.2387174295656609
# Epoch: 5/150 Training Loss: 1.235146954204097
# Epoch: 6/150 Training Loss: 1.2302810757449179
# Epoch: 7/150 Training Loss: 1.2274647589885828
# Epoch: 8/150 Training Loss: 1.22477757117965
# Epoch: 9/150 Training Loss: 1.22316857269316
# Epoch: 10/150 Training Loss: 1.2190834464448872
# Epoch: 11/150 Training Loss: 1.2170018156369526
# Epoch: 12/150 Training Loss: 1.214016981197126
# Epoch: 13/150 Training Loss: 1.2124080883734154
# Epoch: 14/150 Training Loss: 1.2090246505809552
# Epoch: 15/150 Training Loss: 1.2069903458609725
# ...

# %%
# df = pd.DataFrame(columns=('A', 'B', 'C', 'D'))
df = pd.DataFrame(np.nan, index = [0],columns=['A', 'B', 'C', 'D', 'E', 'F', 'G'])
df.loc[0] = ['MarineSediment', 'D18O', np.nan, np.nan, np.nan, np.nan, np.nan ]
df.loc[1] = ['MarineSediment', 'D18O','NA', np.nan, np.nan, np.nan, np.nan]
# df.loc[2] = ['MarineSediment', 'D18O','NA', 'NA', np.nan, np.nan, np.nan]
# df.loc[3] = ['MarineSediment', 'D18O','NA', 'NA', 'temperature', np.nan, np.nan]
# df.loc[4] = ['MarineSediment', 'D18O','NA', 'NA', 'temperature', 'degC', np.nan]

values_to_add = {'A': 'MarineSediment', 'D': 'temperature'}
row_to_add = pd.Series(values_to_add, name = 0)

df = df.append(row_to_add)

# %%
df
# Out:
#                 A     B    C            D   E   F   G
# 0  MarineSediment  D18O  NaN          NaN NaN NaN NaN
# 1  MarineSediment  D18O   NA          NaN NaN NaN NaN
# 0  MarineSediment   NaN  NaN  temperature NaN NaN NaN

# %%
# Date : 05/02/21
# %run train_lstm.py -e 150 -l 0.01
# Out:
# list of len {'1': 14, '2': 112, '3': 147, '3_units': 160, '4': 243, '5': 459, '6': 465}
# 1563
#
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/150 Training Loss: 1.2454383008668513
# Epoch: 1/150 Training Loss: 0.8521493665131507
# Epoch: 2/150 Training Loss: 0.815603841211378
# Epoch: 3/150 Training Loss: 0.8000777738610494
# Epoch: 4/150 Training Loss: 0.7909377592126119
# Epoch: 5/150 Training Loss: 0.7861258039359784
# Epoch: 6/150 Training Loss: 0.7824301693038023
# Epoch: 7/150 Training Loss: 0.7800178665066093
# Epoch: 8/150 Training Loss: 0.7777971963292545
# Epoch: 9/150 Training Loss: 0.7758609574684983
# Epoch: 10/150 Training Loss: 0.7745574083934534
# Epoch: 11/150 Training Loss: 0.773836266748684
# Epoch: 12/150 Training Loss: 0.7725268235730961
# Epoch: 13/150 Training Loss: 0.7717251703911221
# ...

# %%
# Date : 05/02/21
# %run train_lstm.py -e 100 -l 0.001 -u
# Out:
# list of len {'1': 14, '2': 112, '3': 147, '3_units': 160, '4': 243, '5': 459, '6': 465}
# 1563
#
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/100 Training Loss: 2.288956446745961
# Epoch: 1/100 Training Loss: 1.4579400397657938
# Epoch: 2/100 Training Loss: 1.3709617107594545
# Epoch: 3/100 Training Loss: 1.3402289062021524
# Epoch: 4/100 Training Loss: 1.3255945308921264
# Epoch: 5/100 Training Loss: 1.3172626999235644
# Epoch: 6/100 Training Loss: 1.3118863699772103
# Epoch: 7/100 Training Loss: 1.3081213375137435
# Epoch: 8/100 Training Loss: 1.3052763578408362
# Epoch: 9/100 Training Loss: 1.3030706168859685
# Epoch: 10/100 Training Loss: 1.3012941133525364
# Epoch: 11/100 Training Loss: 1.2997685048178709
# Epoch: 12/100 Training Loss: 1.2984413158442967
# Epoch: 13/100 Training Loss: 1.297268207540217
# Epoch: 14/100 Training Loss: 1.2961158424718273
# Epoch: 15/100 Training Loss: 1.2950938505815066
# ...

# %%
# Date : 04/29/21
# %run train_lstm_author.py -e 150 -l 0.005
# Out:
# list of len {'1': 1701, '2': 1873, '3': 3757, '4_units': 3817, '4': 4106, '5': 4261, '6': 5512, '7': 5518}
# 28839
#
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/150 Training Loss: 2.3313119366406574
# Epoch: 1/150 Training Loss: 1.520378277473843
# Epoch: 2/150 Training Loss: 1.3762970613859773
# Epoch: 3/150 Training Loss: 1.289304261355056
# Epoch: 4/150 Training Loss: 1.2355773182669045
# Epoch: 5/150 Training Loss: 1.2023305942102807
# Epoch: 6/150 Training Loss: 1.1813041356830662
# Epoch: 7/150 Training Loss: 1.1626137144786794
# Epoch: 8/150 Training Loss: 1.148040692830823
# Epoch: 9/150 Training Loss: 1.1334594778998202
# Epoch: 10/150 Training Loss: 1.1209406619219435
# Epoch: 11/150 Training Loss: 1.109686368109844
# Epoch: 12/150 Training Loss: 1.0989557293682164
# Epoch: 13/150 Training Loss: 1.0895411318929744
# ...

# %%
# Date : 04/29/21
# %run train_lstm_author.py -e 100 -l 0.005 -u
# Out:
# list of len {'1': 1701, '2': 1873, '3': 3757, '4_units': 3817, '4': 4106, '5': 4261, '6': 5512, '7': 5518}
# 28839
#
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/100 Training Loss: 2.8686182056505656
# Epoch: 1/100 Training Loss: 2.093136863200525
# Epoch: 2/100 Training Loss: 1.9534367064839786
# Epoch: 3/100 Training Loss: 1.8789960318004961
# Epoch: 4/100 Training Loss: 1.8317235609919755
# Epoch: 5/100 Training Loss: 1.7966358948409353
# Epoch: 6/100 Training Loss: 1.7667966032355922
# Epoch: 7/100 Training Loss: 1.739255398819127
# Epoch: 8/100 Training Loss: 1.7193131655761875
# Epoch: 9/100 Training Loss: 1.6962062751304652
# Epoch: 10/100 Training Loss: 1.673957045545283
# Epoch: 11/100 Training Loss: 1.6522454605069767
# Epoch: 12/100 Training Loss: 1.6319362068503993
# Epoch: 13/100 Training Loss: 1.608656776729728
# Epoch: 14/100 Training Loss: 1.5866568121303808
# Epoch: 15/100 Training Loss: 1.56741667080581
# ...

# %%
# Date : 05/11/21
# %run train_lstm.py -e 150 -l 0.01
# Out:
# list of len {'1': 15, '2': 99, '3': 142, '3_units': 146, '4': 230, '5': 407, '6': 412}
# 1418
#
# Training Data for the chain archiveType -> proxyObservationType -> interpretation/variable -> interpretation/variableDetail -> inferredVariable -> inferredVarUnits
#
# Epoch: 0/150 Training Loss: 1.5549409410975001
# Epoch: 1/150 Training Loss: 0.9085026979446411
# Epoch: 2/150 Training Loss: 0.8408089908393653
# Epoch: 3/150 Training Loss: 0.8190686965847874
# Epoch: 4/150 Training Loss: 0.8064179538606523
# Epoch: 5/150 Training Loss: 0.7984888789890049
# Epoch: 6/150 Training Loss: 0.7931430119651932
# Epoch: 7/150 Training Loss: 0.7883235978650617
# Epoch: 8/150 Training Loss: 0.7847734448072072
# Epoch: 9/150 Training Loss: 0.7824177645348214
# Epoch: 10/150 Training Loss: 0.7810066943770057
# Epoch: 11/150 Training Loss: 0.7783179336839968
# Epoch: 12/150 Training Loss: 0.7771799779153085
# Epoch: 13/150 Training Loss: 0.7743086234943287
# ...

# %%
# Date : 05/11/21
# %run train_lstm.py -e 100 -l 0.001 -u
# Out:
# list of len {'1': 15, '2': 99, '3': 142, '3_units': 146, '4': 230, '5': 407, '6': 412}
# 1418
#
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/100 Training Loss: 2.8745349108635843
# Epoch: 1/100 Training Loss: 1.6311277666607418
# Epoch: 2/100 Training Loss: 1.4087947478165497
# Epoch: 3/100 Training Loss: 1.3374174682943671
# Epoch: 4/100 Training Loss: 1.302645347139857
# Epoch: 5/100 Training Loss: 1.2822426332009804
# Epoch: 6/100 Training Loss: 1.2687513924933769
# Epoch: 7/100 Training Loss: 1.2590081294377644
# Epoch: 8/100 Training Loss: 1.251531245472195
# Epoch: 9/100 Training Loss: 1.2455508096798047
# Epoch: 10/100 Training Loss: 1.240630276568301
# Epoch: 11/100 Training Loss: 1.2364524592150439
# Epoch: 12/100 Training Loss: 1.2328617937929995
# Epoch: 13/100 Training Loss: 1.229687804574365
# Epoch: 14/100 Training Loss: 1.2268113241539345
# Epoch: 15/100 Training Loss: 1.2241944482734612
# ...
