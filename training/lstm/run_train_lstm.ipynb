# %%
# %run train_lstm.py -e 100 -l 0.01 -u
# Out:
# Training Data for the chain archiveType -> proxyObservationType -> proxyObservationTypeUnits
#
# Epoch: 0/100 Loss: 1.472440242767334
# Epoch: 1/100 Loss: 1.2975660562515259
# Epoch: 2/100 Loss: 1.2751544713974
# Epoch: 3/100 Loss: 1.2662590742111206
# Epoch: 4/100 Loss: 1.2503703832626343
# Epoch: 5/100 Loss: 1.2417560815811157
# Epoch: 6/100 Loss: 1.2315325736999512
# Epoch: 7/100 Loss: 1.2271367311477661
# Epoch: 8/100 Loss: 1.2100248336791992
# Epoch: 9/100 Loss: 1.2039337158203125
# Epoch: 10/100 Loss: 1.204504370689392
# Epoch: 11/100 Loss: 1.1983424425125122
# Epoch: 12/100 Loss: 1.2001973390579224
# Epoch: 13/100 Loss: 1.1998294591903687
# Epoch: 14/100 Loss: 1.1762555837631226
# Epoch: 15/100 Loss: 1.161957859992981
# Epoch: 16/100 Loss: 1.185692548751831
# Epoch: 17/100 Loss: 1.1631916761398315
# Epoch: 18/100 Loss: 1.175552487373352
# Epoch: 19/100 Loss: 1.1487555503845215
# Epoch: 20/100 Loss: 1.1354540586471558
# Epoch: 21/100 Loss: 1.1658931970596313
# ...
