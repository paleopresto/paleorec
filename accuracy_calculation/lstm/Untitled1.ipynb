# %%
# %run fang_metrics.py
# Out:
# ref word MarineSediment for lis item MarineSediment
# actual length = 13, received length = 13
# ref word D18O for lis item D18O
# actual length = 13, received length = 9
# ref word NA for lis item NA
# actual length = 13, received length = 6
# ref word NA for lis item NA
# actual length = 13, received length = 11
# ref word surface.temp for lis item surface.temp
# actual length = 1, received length = 1
# ref word MarineSediment for lis item MarineSediment
# actual length = 13, received length = 13
# ref word Notes for lis item Notes
# actual length = 1, received length = 1
# ref word NA for lis item NA
# actual length = 13, received length = 5
# ref word NA for lis item NA
# actual length = 13, received length = 13
# ref word NA for lis item NA
# actual length = 13, received length = 2
# ref word MarineSediment for lis item MarineSediment
# actual length = 13, received length = 13
# ref word D18O for lis item D18O
# actual length = 13, received length = 9
# ...
